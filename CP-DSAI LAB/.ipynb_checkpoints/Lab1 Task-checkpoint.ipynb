# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

boston = load_boston()
X = boston.data
y = boston.target
m = X.shape[0]  
n = X.shape[1]

scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
intercept = np.ones((X_train.shape[0], 1))

X_train = np.concatenate((intercept, X_train), axis=1)

intercept = np.ones((X_test.shape[0], 1))

X_test = np.concatenate((intercept, X_test), axis=1)


alpha = 0.001
max_iter = 1000
loss_old = 10000
tol = 0.0001
iter_stop = 0
method = "minibatch"
used_num = []

def h_theta(X, theta):
    return X @ theta

def mse(yhat, y_i):
    return ((yhat - y_i)**2).sum() / yhat.shape[0]

def gradient(X, error):
    return X.T @ error

for i in range(max_iter):
    if method == "stochastic":
        i = np.random.randint(X_train.shape[0])
        if i not in used_num:
            used_num.append(i)
        else:
            i = np.random.randint(X_train.shape[0])
        
        X_i = X_train[i]
        
        X_train = X_i.reshape(1,-1)
        
        theta = np.zeros(X_train.shape[1])
        
        y_i = y_train.reshape(-1,1)
        
        y_i = y_i[i]
        
    elif method == "minibatch":
        
        i = np.random.randint(X_train.shape[0])
        
        X_i = X_train[i:i + 100]
        
        #print("X_i shape is ", X_i.shape)
        
        #print("X_train shape is ", X_train.shape)
        theta = np.zeros(X_train.shape[1])
        
        #print("theta shape is ", theta.shape)
        
        y_i = y_train.reshape(-1,1)
        
        y_i = y_i[i]
        
    yhat = h_theta(X_train, theta)
    #print("yhat is ", yhat.shape)
    #print("y_i is ", y_i.shape)
    error = yhat - y_i
    #print("error shape is ",error.shape)
    
    loss_new = mse(yhat,y_i)
    if np.abs(loss_new-loss_old) < tol:
        break
 
    grad = gradient(X_train, error)

    theta = theta - alpha * grad
    
    
yhat = h_theta(X_test, theta)

mse = mse(yhat,y_test)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14428/3958674321.py in <module>
#      85         break
#      86
# ---> 87     grad = gradient(X_train, error)
#      88
#      89     theta = theta - alpha * grad
#
# ~\AppData\Local\Temp/ipykernel_14428/3958674321.py in gradient(X, error)
#      39
#      40 def gradient(X, error):
# ---> 41     return X.T @ error
#      42
#      43 for i in range(max_iter):
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 53 is different from 354)
